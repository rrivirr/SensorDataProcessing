# %%
b1<-readRDS("/Users/jdh/SensorDataProcessing/rriv_methane/anya_methane/slopes_compiled_b1.rds")
b2<-readRDS("/Users/jdh/SensorDataProcessing/rriv_methane/anya_methane/slopes_compiled_b2.rds")
b3<-readRDS("/Users/jdh/SensorDataProcessing/rriv_methane/anya_methane/slopes_compiled_b3.rds")

# %%
library(dplyr)
library(ggplot2)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
b123<-bind_rows(b1,b2,b3)
head(b123$start_time)
# Out:
# [1] "2023-07-11 18:30:18 UTC" "2023-07-11 20:30:18 UTC"
# [3] "2023-07-11 22:30:18 UTC" "2023-07-12 00:30:18 UTC"
# [5] "2023-07-12 02:30:18 UTC" "2023-07-12 04:30:18 UTC"

# %%
b123p<-subset(b123,slope>0)

ggplot(b123p,aes(b_id,slope,group=b_id))+geom_boxplot()+xlab("Bucket ID")+ylab(expression("Change"~CH[4]~"("*ppm-s^-1*")"))
# Out:
# plot without title

# %%
attr(b123p$start_time, "tzone") <- "EST"
b123p$start_time
ggplot(b123p,aes(start_time,slope,color=as.factor(b_id)))+geom_point()
ggsave("time_series_ch4.pdf", width = 20, height = 20, units = "cm")
# Out:
#   [1] "2023-07-11 13:30:18 EST" "2023-07-11 17:30:18 EST"
#   [3] "2023-07-11 21:30:18 EST" "2023-07-12 01:30:18 EST"
#   [5] "2023-07-12 05:30:18 EST" "2023-07-12 09:30:18 EST"
#   [7] "2023-07-12 12:30:18 EST" "2023-07-12 14:30:18 EST"
#   [9] "2023-07-12 16:30:18 EST" "2023-07-12 18:30:18 EST"
#  [11] "2023-07-12 20:30:18 EST" "2023-07-12 22:30:18 EST"
#  [13] "2023-07-13 00:30:18 EST" "2023-07-13 02:30:18 EST"
#  [15] "2023-07-13 06:30:18 EST" "2023-07-13 08:30:18 EST"
#  [17] "2023-07-13 13:30:18 EST" "2023-07-13 17:30:18 EST"
#  [19] "2023-07-14 01:30:18 EST" "2023-07-14 05:30:18 EST"
#  [21] "2023-07-14 10:30:18 EST" "2023-07-14 12:30:18 EST"
#  [23] "2023-07-14 14:30:18 EST" "2023-07-14 16:30:18 EST"
#  [25] "2023-07-14 18:30:18 EST" "2023-07-14 20:30:18 EST"
#  [27] "2023-07-14 22:30:18 EST" "2023-07-15 00:30:18 EST"
#  [29] "2023-07-15 02:30:18 EST" "2023-07-15 04:30:18 EST"
#  [31] "2023-07-15 06:30:18 EST" "2023-07-15 09:30:18 EST"
# ...
