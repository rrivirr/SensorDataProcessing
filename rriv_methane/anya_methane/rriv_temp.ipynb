# %% [markdown]
# # Setup

# %%
# is this the folder with the script in it?
scriptDir<-getwd()
scriptDir

# if not, uncomment and use this instead
# scriptDir<-""
# Out:
# [1] "/Users/anyaemerson/Documents/github/emersonae/SensorDataProcessing/rriv_methane/anya_methane"

# %%
methaneFunctions<-paste(scriptDir,"/methane_functions.r",sep="")
methaneFunctions
if (file.exists(methaneFunctions)){
    source(methaneFunctions)
} else {
    print("manually correct the location and/or name of methane_functions.r")
}
# Out:
# [1] "/Users/anyaemerson/Documents/github/emersonae/SensorDataProcessing/rriv_methane/anya_methane/methane_functions.r"

# %%
# Package names
packages <- c("data.table","zoo","tidyverse","dplyr", "doBy", "lubridate", "ggplot2", "Hmisc", "zoo", "viridis", "gam", "ggeffects", "reshape2", "mgcv")
packageHandler(packages)
# Out:
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.2     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.2     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::between()     masks data.table::between()
# ✖ dplyr::filter()      masks stats::filter()
# ✖ dplyr::first()       masks data.table::first()
# ✖ lubridate::hour()    masks data.table::hour()
# ✖ lubridate::isoweek() masks data.table::isoweek()
# ✖ dplyr::lag()         masks stats::lag()
# ✖ dplyr::last()        masks data.table::last()
# ✖ lubridate::mday()    masks data.table::mday()
# ✖ lubridate::minute()  masks data.table::minute()
# ✖ lubridate::month()   masks data.table::month()
# ...

# %% [markdown]
# # RRIV COMPARE TEST

# %%
dir_rriv<-"~/Library/Mobile\ Documents/com~apple~CloudDocs/Documents/RRIV/Data/test/20230705-rriv-compare/RRIV"
dir_rriv2<-"~/Library/Mobile\ Documents/com~apple~CloudDocs/Documents/RRIV/Data/test/20230705-rriv-compare/20230706"

# %%
# create output directory path based on input directory
outputDir<-"~/Library/Mobile\ Documents/com~apple~CloudDocs/Documents/RRIV/Data/test/20230705-rriv-compare/output"
# create the output directory if necessary
newDir(dirPath = outputDir)
# Out:
# Output directory, ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/RRIV/Data/test/20230705-rriv-compare/output, already exists
# Output directory not found, creating: ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/RRIV/Data/test/20230706-co2-test/output

# %%
#github 
gitDir<-"~/Library/Mobile\ Documents/com~apple~CloudDocs/Documents/github/emersonae/SensorDataProcessing/rriv_methane/anya_methane/figures"

# %%
UUIDdict=c(
"57FF6E068387575148360767"="CAL1",
"57FF6D068387575151290167"="CAL2",
"57FF6F068387575149330867"="CAL3",
"57FF6E068387575140070767"="CAL4",
"50FF74068678545256252467"="CAL5")

rriv_data<-concat_dirs(dir_rriv, read_rriv_CSV, filePattern=".CSV", minFileSize=400)
rriv_data<-process_rriv_columns(rriv_data)
rriv_data<-createSensorColFromIDs(rriv_data,idCol = "uuid",dict = UUIDdict)
saveDFcsv(rriv_data)



rriv_data2<-concat_dirs(dir_rriv2, read_rriv_CSV, filePattern=".CSV", minFileSize=400)
rriv_data2<-process_rriv_columns(rriv_data2)
rriv_data2<-createSensorColFromIDs(rriv_data2,idCol = "uuid",dict = UUIDdict)
saveDFcsv(rriv_data2)
# Out:
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# [1] "Dataframe generated, manually process column types if necessary"
# Warning message:
# “Unknown or uninitialised column: `Sensor`.”
# [1] "~/Library/Mobile Documents/com~apple~CloudDocs/Documents/RRIV/Data/test/20230705-rriv-compare/output/rriv_data.csv"
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# [1] "Dataframe generated, manually process column types if necessary"
# Warning message:
# “Unknown or uninitialised column: `Sensor`.”
# ...

# %% [markdown]
# # plots

# %%
plot1<-ggplot(rriv_data, aes(x=time.h, y=ch4_raw, color=Sensor))+geom_point()+labs(title="RRIV outflow tube vs not 7/5")
# savePlot(plot1,"ch4")
plot1
#CAL1 = no tube 
#CAL4 = tube
# Out:
# plot without title

# %%
plot2<-ggplot(rriv_data2, aes(x=time.h, y=ch4_raw, color=Sensor))+geom_point()+labs(title="RRIV outflow tube vs not 7/6")
plot2
# Out:
# plot without title

# %% [markdown]
# # CO2 TEST

# %%
dir_rriv_co2<-"~/Library/Mobile\ Documents/com~apple~CloudDocs/Documents/RRIV/Data/test/20230706-co2-test/RRIV"
dir_lgr_co2<-"~/Library/Mobile\ Documents/com~apple~CloudDocs/Documents/RRIV/Data/test/20230706-co2-test/LGR"

outputDir2<-"~/Library/Mobile\ Documents/com~apple~CloudDocs/Documents/RRIV/Data/test/20230706-co2-test/output"
newDir(dirPath = outputDir2)
# Out:
# Output directory, ~/Library/Mobile Documents/com~apple~CloudDocs/Documents/RRIV/Data/test/20230706-co2-test/output, already exists

# %%
lgr_data_co2<-concat_dirs(dir_lgr_co2, read_GA_ZIP, filePattern=".zip", minFileSize=400)
    clean_temp()
lgr_data_co2$Time<-lubridate::as_datetime(lgr_data_co2$Time)
saveDFcsv(lgr_data_co2)
# Out:
# [1] "Dataframe generated, manually process column types if necessary"
# [1] "~/Library/Mobile Documents/com~apple~CloudDocs/Documents/RRIV/Data/test/20230705-rriv-compare/output/lgr_data_co2.csv"

# %%
UUIDdict=c(
"57FF6E068387575148360767"="CAL1",
"57FF6D068387575151290167"="CAL2",
"57FF6F068387575149330867"="CAL3",
"57FF6E068387575140070767"="CAL4",
"50FF74068678545256252467"="CAL5")

rriv_data_co2<-concat_dirs(dir_rriv_co2, read_rriv_CSV, filePattern=".CSV", minFileSize=400)
rriv_data_co2<-process_rriv_columns(rriv_data_co2)
rriv_data_co2<-createSensorColFromIDs(rriv_data_co2,idCol = "uuid",dict = UUIDdict)
# saveDFcsv(rriv_data_co2)
# Out:
# New names:
# • `_raw` -> `_raw...12`
# • `_cal` -> `_cal...13`
# • `_raw` -> `_raw...14`
# • `_cal` -> `_cal...15`
# • `_raw` -> `_raw...16`
# • `_cal` -> `_cal...17`
# • `_raw` -> `_raw...18`
# • `_cal` -> `_cal...19`
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Warning message:
# ...

# %%
# start time is the max between the starting points for each range
    # start<-max(range(rriv_data1$time.h,na.rm=TRUE)[1],range(lgr_data1$Time,na.rm=TRUE)[1])
    start<-max(range(rriv_data_co2$time.h)[1],range(lgr_data_co2$Time)[1])
    # start<-lubridate::as_datetime("2023-06-26 19:36:26.981")
# end time is the min between the ending points for each range
    # end<-min(range(rriv_data1$time.h,na.rm=TRUE)[2],range(lgr_data1$Time,na.rm=TRUE)[2])
    end<-min(range(rriv_data_co2$time.h)[2],range(lgr_data_co2$Time)[2])

# subset the rriv data
rriv_data_overlap1<-rriv_data_co2[rriv_data_co2$time.h>start & rriv_data_co2$time.h<end,]
# range(rriv_data_overlap1$time.h,na.rm=TRUE)
range(rriv_data_overlap1$time.h)

# subset the lgr data
lgr_data_overlap1<-lgr_data_co2[lgr_data_co2$Time>start & lgr_data_co2$Time<end,]
# range(lgr_data_overlap1$Time,na.rm=TRUE)
range(lgr_data_overlap1$Time)

rriv_data_ol_raw1<-rriv_data_overlap1[rriv_data_overlap1$type=="raw",]
rriv_data_ol_summary1<-rriv_data_overlap1[rriv_data_overlap1$type=="summary",]
# Out:
# [1] "2023-07-06 14:33:24 UTC" "2023-07-06 16:52:26 UTC"
# [1] "2023-07-06 14:33:33 UTC" "2023-07-06 16:52:49 UTC"

# %%
#grab time, co2 & sensor columns 
rriv_data_overlap1_co2<-data.frame(time = rriv_data_overlap1$time.h,co2=as.numeric(rriv_data_overlap1$co2_CO2_ppm),id=rriv_data_overlap1$Sensor)

lgr_data_overlap1_co2<-data.frame(time = lgr_data_overlap1$Time,co2 = as.numeric(lgr_data_overlap1$X.CO2._ppm),id="LGR")
co2_data_all<-bind_rows(rriv_data_overlap1_co2,lgr_data_overlap1_co2)
# head(rriv_data_overlap1)
# head(lgr_data_overlap1)
# co2_data_all
plot5<-ggplot(co2_data_all, aes(x=time, y=co2, color=id))+geom_point()+labs(title="")
plot5
# Out:
# plot without title

# %%
plot3<-ggplot(rriv_data_overlap1, aes(x=time.h, y=as.numeric(co2_CO2_ppm), color=Sensor))+geom_point()+labs(title="RRIV outflow tube vs not")
plot3
plot4<-ggplot(lgr_data_overlap1, aes(x=Time, y=X.CO2._ppm))+geom_point()+labs(title="LGR, 5 gallon, silicone")
plot4
# Out:
# plot without title
# plot without title
