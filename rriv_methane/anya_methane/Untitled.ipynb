# %%
b1<-readRDS("/Users/jdh/SensorDataProcessing/rriv_methane/anya_methane/slopes_compiled_b1.rds")
b2<-readRDS("/Users/jdh/SensorDataProcessing/rriv_methane/anya_methane/slopes_compiled_b2.rds")
b3<-readRDS("/Users/jdh/SensorDataProcessing/rriv_methane/anya_methane/slopes_compiled_b3.rds")

# %%
library(dplyr)
library(ggplot2)

# %%
b123<-bind_rows(b1,b2,b3)
head(b123)
# Out:
#   start_time          stop_time           round slope        b_id
# 1 2023-07-11 18:30:18 2023-07-11 19:12:43 1      0.015793993 1
# 2 2023-07-11 20:30:18 2023-07-11 21:12:43 2     -0.116244217 1
# 3 2023-07-11 22:30:18 2023-07-11 23:12:43 3      0.020146973 1
# 4 2023-07-12 00:30:18 2023-07-12 01:12:43 4     -0.093865603 1
# 5 2023-07-12 02:30:18 2023-07-12 03:12:43 5      0.003421739 1
# 6 2023-07-12 04:30:18 2023-07-12 05:12:43 6     -0.113899321 1

# %%
b123p<-subset(b123,slope>0)

ggplot(b123p,aes(b_id,slope,group=b_id))+geom_boxplot()
# Out:
# plot without title
